# %% [markdown]
# # foundation test notebook to verify all components are working

# %%
# Updated foundation_test.ipynb with reloading
import os
import sys
from pathlib import Path
import importlib

# Add project root to path
project_root = Path().cwd().parent
sys.path.append(str(project_root))

# %%
# Force reload modules
import AerialObjectDetectionAndClassification.utils.main_utils as main_utils
importlib.reload(main_utils)
# Out:
# DEBUG: Loading main_utils.py - updated version with Path type
# <module 'AerialObjectDetectionAndClassification.utils.main_utils' from 'c:\\Users\\Venks\\Desktop\\Project\\MLOPS_Bootcamp\\Deep Learning\\Computer_Vision\\Aerial_Object_Classification_And_Detection\\AerialObjectDetectionAndClassification\\utils\\main_utils.py'>

# %%
import AerialObjectDetectionAndClassification.configuration.config as config
importlib.reload(config)
# Out:
# <module 'AerialObjectDetectionAndClassification.configuration.config' from 'c:\\Users\\Venks\\Desktop\\Project\\MLOPS_Bootcamp\\Deep Learning\\Computer_Vision\\Aerial_Object_Classification_And_Detection\\AerialObjectDetectionAndClassification\\configuration\\config.py'>

# %%
# Now test
from AerialObjectDetectionAndClassification.constant.application import *
print("ROOT_DIR:", ROOT_DIR)
print("CONFIG_FILE_PATH:", CONFIG_FILE_PATH)

from AerialObjectDetectionAndClassification.configuration.config import ConfigurationManager

config_manager = ConfigurationManager()
# Out:
# ROOT_DIR: c:\Users\Venks\Desktop\Project\MLOPS_Bootcamp\Deep Learning\Computer_Vision\Aerial_Object_Classification_And_Detection
# CONFIG_FILE_PATH: c:\Users\Venks\Desktop\Project\MLOPS_Bootcamp\Deep Learning\Computer_Vision\Aerial_Object_Classification_And_Detection\config.yaml
# Created directory at: artifacts
